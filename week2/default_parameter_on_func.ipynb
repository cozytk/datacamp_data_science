# %% [markdown]
# # mutable & immutable parameter
# ## 들어가기
# ### 개념
# - default parameter
# - scope
# - mutable / immutable
#
# ## Default parameter

# %% [markdown]
# ## Mutable & Immutable parameter
# ### Mutable
# 값을 변경할 수 있는 자료형

# %%
a = [1, 2, 3]
a[0] = 4
a
# Out:
# [4, 2, 3]

# %%
a = (1, 2, 3)
a[0] = 4
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zz/zyxvpxvq6csfxvn_n000cbyw0032zq/T/ipykernel_29698/2053128010.py in <module>
#       1 a = (1, 2, 3)
# ----> 2 a[0] = 4
#       3 a
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = [1, 2, 3]
b = a
b[0] = 4
a
# Out:
# [4, 2, 3]

# %% [markdown]
# ### 해결책
# ```python
# import copy as cp
#
# ### shallow copy (얕은 복사)
# list(a)
# a[:]
# a.copy()
# cp.copy(a)
#
# ### deep copy (깊은복사)
# cp.deepcopy(a)
# ```

# %% [markdown]
# ### scope
# scope는 변수가 유효한 구역을 의미함. 함수안에 들어가면 지역, 함수밖에서는 전역.
#
# 함수안에 들어간 변수는 지역변수, 함수밖에서는 전역변수.
#
#
# ※ argument는 인자, parameter는 매개변수라고 부름
#
# argument는 var로 전해지는 것이 인자. 매개변수는 함수 스코프 안에서 변수가 매개변수
# ### mutable argument, immutable argument

# %%
def foo(x, y):
    x[0] = 99
    print(id(x) == y)

my_list = [1,2,3]
foo(my_list, id(my_list))
my_list
# Out:
# True
# [99, 2, 3]

# %%
def bar(x, y):
    x = x + 10
    print(id(x) == y)

my_var = 3
bar(my_var, id(my_var))
my_var
# Out:
# False
# 3

# %% [markdown]
# mutable argument는 parmeter와 동일하지만,
#
# immutable한 argument는 parameter와 다르다!
#
# ## 심화
# ## Default parameter

# %%
def calculator_kr(arg1, arg2, cmd='더하기'):
    if cmd == '더하기':
        return arg1 + arg2
    elif cmd == '빼기':
        return arg1 - arg2

calculator_kr(3, 4, '더하기')
# Out:
# 7

# %%
calculator_kr(4, 3, '빼기')
# Out:
# 1

# %%
calculator_kr(3, 4)
# Out:
# 7

# %% [markdown]
# ### 예시
# 우리가 흔히 사용하는 print도 여러가지 디폴트 매개변수가 있음
# 대표적으로 인자간 출력되는 간격인 sep은 ' ' -> 띄어쓰기. 마침표인 end는 '\n' -> 엔터

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ### empty list default argument

# %%
def foo(var=[]):
    var.append(1)
    return var
foo()
# Out:
# [1]

# %%
foo()
# Out:
# [1, 1, 1, 1, 1]

# %%
foo([3])
# Out:
# [3, 1]

# %%
def foo(var=None):
    if var is None:
        var = []
    var.append(1)
    return var
foo()
# Out:
# [1]

# %%
foo()
# Out:
# [1]

# %%
def foo(var=[]):
    if not var:
        var = []
    var.append(1)
    return var

# %%
foo()
# Out:
# [1]

# %%
foo([2])
foo()
# Out:
# [1]

# %%
print(type(ZeroDivisionError))

AssertionError
# Out:
# <class 'type'>

# %%
import datetime

from typing import Optional

def log_typed(message: str,
              when: Optional[datetime]=None) -> None:
    """메시지와 타임스탬프를 로그에 남긴다.

    Args:
        message: 출력할 메시지.
        when: 메시지가 발생한 시각(datetime).
            디폴트 값은 현재 시간이다.
    """
    if when is None:
        when = datetime.now()
    print(f'{when}: {message}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_45446/1416624789.py in <module>
#       4
#       5 def log_typed(message: str,
# ----> 6               when: Optional[datetime]=None) -> None:
#       7     """메시지와 타임스탬프를 로그에 남긴다.
#       8
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/typing.py in inner(*args, **kwds)
#     259         except TypeError:
#     260             pass  # All real errors (not unhashable args) are raised below.
# --> 261         return func(*args, **kwds)
#     262     return inner
#     263
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/typing.py in __getitem__(self, parameters)
#     362             return _GenericAlias(self, parameters)
#     363         if self._name == 'Optional':
# --> 364             arg = _type_check(parameters, "Optional[t] requires a single type.")
#     365             return Union[arg, type(None)]
#     366         if self._name == 'Literal':
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/typing.py in _type_check(arg, msg, is_argument)
#     147         return arg
#     148     if not callable(arg):
# --> 149         raise TypeError(f"{msg} Got {arg!r:.100}.")
#     150     return arg
#     151
#
# TypeError: Optional[t] requires a single type. Got <module 'datetime' from '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Ve.

# %%
log_typed("Hi", [1,2,3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_45446/3514332538.py in <module>
# ----> 1 log_typed("Hi", [1,2,3])
#
# NameError: name 'log_typed' is not defined
